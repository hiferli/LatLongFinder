# %% [markdown]
# <a href="https://colab.research.google.com/github/hiferli/LatLongFinder/blob/main/PGeoCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing Dependencies
pip install pgeocode

# %%
import pgeocode
import pandas as pd

# %%
# Function to get Latitude and Longitude from the Pincode and Country
def pinToLatLong(postalcode, country='in'):
    nomi = pgeocode.Nominatim(country)
    location = nomi.query_postal_code(postalcode)
    return location.latitude, location.longitude

# %%
# Reading Data from CSV File
df = pd.read_csv('/content/Pin_code.csv')

# %%
print(df)

# %%
# Making new columns for Lat and Long for every Pincode in the Dataframe
df[['Latitude', 'Longitude']] = df['PIN Code'].apply(pinToLatLong).apply(pd.Series)

# %%
df
# Out:
#        PIN Code  Latitude  Longitude
# 0        400009   18.9474    72.8138
# 1        400010   18.9681    72.8450
# 2        400012   19.0000    72.8333
# 3        400014   19.0073    72.8421
# 4        400016   19.0073    72.8421
# ...         ...       ...        ...
# 17366    160079       NaN        NaN
# 17367    160106       NaN        NaN
# 17368    133301   30.8398    76.9406
# 17369    133302   30.8398    76.9406
# 17370    134101   30.7987    76.9182
#
# [17371 rows x 3 columns]

# %%
# Convert to CSV File
df.to_csv("Final.csv")

# %%
# Import Drive API and authenticate.
from google.colab import drive

# Mount your Drive to the Colab VM.
drive.mount('/gdrive')

# Write the DataFrame to CSV file.
with open('/gdrive/My Drive/foo.csv', 'w') as f:
  df.to_csv(f)
# Out:
# Mounted at /gdrive
